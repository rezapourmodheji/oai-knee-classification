# %%
import pandas as pd
import os
import tarfile
import re
import pydicom  # Ensure pydicom is installed: pip install pydicom

# %%
# Define paths
study = '/home/reza/oai-knee-classification/'
data_raw = study + 'Data_Raw/'
base_image_path = data_raw + 'images/00m/'
outinfo_path = data_raw + '/output_info/'
scores_path = data_raw + '/scores/'
baseimage_folders = ['0.C.2','0.E.1']

# %%
mapping_csv = outinfo_path + 'subject_folder_mapping.csv'
output_base_path = "~/oai-knee-classification/Data_Reduced/dicoms"

# Load mapping CSV
mapping_df = pd.read_csv(os.path.expanduser(mapping_csv))

# Filter valid subject folders with date folders
valid_df = mapping_df[mapping_df['date_folders'] != 'No date folders found']
print( valid_df['src_subject_id'].nunique())
subset_df = valid_df.iloc[1:11]
# Out:
# 4796

# %%
def is_dicom_file(filepath):
    """
    Checks if a given file is a DICOM file.

    Args:
        filepath (str): The path to the file.

    Returns:
        bool: True if the file is a DICOM file, False otherwise.
    """
    try:
        # Attempt to read the DICOM file
        pydicom.dcmread(filepath)
        return True
    except pydicom.errors.InvalidDicomError:
        # If an InvalidDicomError is raised, it's not a valid DICOM file
        return False
    except FileNotFoundError:
        # Handle cases where the file doesn't exist
        print(f"Error: File not found at {filepath}")
        return False
    except Exception as e:
        # Catch other potential errors during file reading
        print(f"An unexpected error occurred: {e}")
        return False

# Function to check if extracted DICOMs are knee images
def is_knee_dicom(extracted_path):
    for file_name in os.listdir(extracted_path):
        # print(file_name)
        dcm_path = os.path.join(extracted_path, file_name)
        try:
            ds = pydicom.dcmread(dcm_path)
            
            # Check BodyPartExamined (0018,0015) for "KNEE"
            body_part = ds.get((0x0018, 0x0015), None)
            study_ID = ds.get((0x0008, 0x0060), None)
            
            if body_part and 'KNEE' in body_part.value.upper() and \
                ('CR' in study_ID.value.upper() or 'DX' in study_ID.value.upper()):
                return True
            # Fallback: Check SeriesDescription (0008,103E) for "knee"
            # series_desc = ds.get((0x0008, 0x103E), None)
            # if series_desc and 'KNEE' in series_desc.value.upper():
            #     return True
        except Exception as e:
            print(f"Error reading DICOM {dcm_path}: {str(e)}")
    return False

# %%
# Initialize results
extracted_files = []

# Process each subject
for _, row in subset_df.iterrows():
    subject_id = str(row['src_subject_id']).strip()
    subject_folder_path = row['subject_folder_path']
    date_folders = row['date_folders'].split(',')

    for date_folder in date_folders:
        if not re.match(r'^\d{8}$', date_folder):
            continue  # Skip invalid dates

        # Source folder
        src_folder = os.path.join(subject_folder_path, date_folder)
        if not os.path.exists(src_folder):
            continue

        # Output folder (temporary for extraction)
        temp_out_folder = os.path.expanduser(
            f"{output_base_path}/{subject_id}/{date_folder}_temp"
        )
        os.makedirs(temp_out_folder, exist_ok=True)

        # Extract .tar.gz files
        for file_name in os.listdir(src_folder):
            if file_name.endswith('.tar.gz'):
                tar_path = os.path.join(src_folder, file_name)
                try:
                    with tarfile.open(tar_path, 'r:gz') as tar:
                        tar.extractall(path=temp_out_folder)

                    final_out_folder = os.path.expanduser(
                            f"{output_base_path}/{subject_id}/{date_folder}/{file_name[:-7]}"  # Remove .tar.gz
                        )
                    os.makedirs(os.path.dirname(final_out_folder), exist_ok=True)
                    
                    
                    # Check if it's a knee image
                    if is_knee_dicom(temp_out_folder):
                        # Move to final path if it's knee
                        final_out_folder = os.path.expanduser(
                            f"{output_base_path}/{subject_id}/{date_folder}/{file_name[:-7]}"  # Remove .tar.gz
                        )
                        os.makedirs(os.path.dirname(final_out_folder), exist_ok=True)
                        os.rename(temp_out_folder, final_out_folder)
                        extracted_files.append({
                            'src_subject_id': subject_id,
                            'date_folder': date_folder,
                            'tar_file': file_name,
                            'extracted_path': final_out_folder,
                            'is_knee': True
                        })
                        print(f"Kept knee DICOMs for {subject_id}/{date_folder}/{file_name}")
                    else:
                        # Delete non-knee extraction
                        for root, dirs, files in os.walk(temp_out_folder, topdown=False):
                            for name in files:
                                os.remove(os.path.join(root, name))
                            for name in dirs:
                                os.rmdir(os.path.join(root, name))
                        os.rmdir(temp_out_folder)
                        extracted_files.append({
                            'src_subject_id': subject_id,
                            'date_folder': date_folder,
                            'tar_file': file_name,
                            'extracted_path': 'Deleted (not knee)',
                            'is_knee': False
                        })
                        print(f"Deleted non-knee DICOMs for {subject_id}/{date_folder}/{file_name}")
                except Exception as e:
                    extracted_files.append({
                        'src_subject_id': subject_id,
                        'date_folder': date_folder,
                        'tar_file': file_name,
                        'extracted_path': f"Error: {str(e)}",
                        'is_knee': False
                    })
                    # Clean up temp if error
                    if os.path.exists(temp_out_folder):
                        for root, dirs, files in os.walk(temp_out_folder, topdown=False):
                            for name in files:
                                os.remove(os.path.join(root, name))
                            for name in dirs:
                                os.rmdir(os.path.join(root, name))
                        os.rmdir(temp_out_folder)

# Save extraction log to CSV
output_df = pd.DataFrame(extracted_files)
output_csv = outinfo_path + 'extraction_log.csv'
output_df.to_csv(os.path.expanduser(output_csv), index=False)
print(f"Saved extraction log with {len(output_df)} entries to {output_csv}")
# Out:
# Kept knee DICOMs for 9543202/20040209/00007104.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000203.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000202.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000210.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000205.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000214.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000201.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000212.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/00020604.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000208.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000206.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000204.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000207.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000209.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000211.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/10000213.tar.gz
# Deleted non-knee DICOMs for 9543202/20040223/00020704.tar.gz
# Kept knee DICOMs for 9400081/20040204/00000104.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000314.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000303.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/00002705.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000305.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000304.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000311.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000306.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000302.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000307.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000309.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000310.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/00002704.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000313.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000301.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000312.tar.gz
# Deleted non-knee DICOMs for 9400081/20040225/10000308.tar.gz
# Kept knee DICOMs for 9546159/20040212/00007404.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000406.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000407.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000412.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000401.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000403.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000411.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000404.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000408.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000414.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000402.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000415.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000405.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000409.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000410.tar.gz
# Deleted non-knee DICOMs for 9546159/20040225/10000413.tar.gz
# Deleted non-knee DICOMs for 9546159/20040226/00020104.tar.gz
# Deleted non-knee DICOMs for 9546159/20040226/00020304.tar.gz
# Kept knee DICOMs for 9547154/20040210/00007204.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000006.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000010.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000007.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000009.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/00005405.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000012.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000001.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000005.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000014.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000003.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000013.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000008.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000002.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/00005404.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000011.tar.gz
# Deleted non-knee DICOMs for 9547154/20040225/10000004.tar.gz
# Kept knee DICOMs for 9553149/20040213/00007704.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000607.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000612.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000613.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000602.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000614.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000609.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000606.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/00020504.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000604.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000601.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000603.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000610.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/00020404.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000605.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000608.tar.gz
# Deleted non-knee DICOMs for 9553149/20040226/10000611.tar.gz
# Kept knee DICOMs for 9406033/20040213/00000204.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004902.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/00004004.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004903.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004909.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004913.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004911.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004901.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/00004005.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004914.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004907.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004912.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004904.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004908.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004905.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004910.tar.gz
# Deleted non-knee DICOMs for 9406033/20040301/10004906.tar.gz
# Kept knee DICOMs for 9547677/20040219/00009604.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003330.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003336.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003334.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003341.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003342.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003337.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003333.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003339.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003335.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003338.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003332.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003331.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003329.tar.gz
# Deleted non-knee DICOMs for 9547677/20040227/10003340.tar.gz
# Kept knee DICOMs for 9562160/20040216/00009004.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002704.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002708.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002702.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002712.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002709.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002710.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002706.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002707.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002714.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/00006205.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/00006204.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002703.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002713.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002705.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002701.tar.gz
# Deleted non-knee DICOMs for 9562160/20040301/10002711.tar.gz
# Kept knee DICOMs for 9555149/20040213/00007604.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002108.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002112.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002103.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002110.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/00006004.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002114.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002113.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002102.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002107.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/00006005.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002106.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002101.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002105.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002109.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10002104.tar.gz
# Deleted non-knee DICOMs for 9555149/20040302/10751801.tar.gz
# Kept knee DICOMs for 9570722/20040223/00010304.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002510.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002502.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002511.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002501.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002512.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002509.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002505.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002508.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10319801.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002506.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002513.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/00005604.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002514.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002503.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/10002507.tar.gz
# Deleted non-knee DICOMs for 9570722/20040302/00005605.tar.gz
# Saved extraction log with 169 entries to /home/reza/oai-knee-classification/Data_Raw//output_info/extraction_log.csv
